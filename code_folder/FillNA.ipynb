# %% [markdown]
# # Stochastic Regression Imputation
#
# The groundwater dataset has a significant fraction of NA values.<br> In this, we'll be using stochastic regression imputation in order to fill them.<br><br>
#
# First, the necessary libraries are imported.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# The missing values are filled in by using linear regression, using records who don't have missing values<br>
# as the training set. The parameters are obtained and and used to fit the records with the missing data.

# %%
def linReg(x_train, y_train, x_test):
    ones = np.ones([x_train.shape[0], 1])
    x_train = np.concatenate((ones, x_train), axis=1)
    ones = np.ones([x_test.shape[0], 1])
#  x_test = np.reshape(x_test,[x_test.shape[0],1])
    x_test = np.concatenate((ones, x_test), axis=1)
    temp_1 = np.dot(x_train.T, x_train)
    temp_1 = temp_1.astype(np.float64)
    temp_1 = np.linalg.pinv(temp_1)
    temp_2 = np.dot(x_train.T, y_train)
    theta = np.dot(temp_1, temp_2)
    preds = np.dot(x_test, theta)
    return preds

# %% [markdown]
# In the next couple cells, all the files are iterated through and compiled into one large dataset, and <br>
# unecessary features are removed.

# %%
places =['andhra_pradesh','assam','bihar','chattissgarh','daman_diu_dadra_nagar_haveli','goa','himachal_pradesh','kerala','lakshadweep','madhya_pradesh','maharashtra','odisha','pondicherry','punjab','rajasthan','tripura','uttar_pradesh_uttarakhand','west_bengal']

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()

for place in places:
    
    df = pd.read_csv("../data_folder/groundwater_folder/ground_water_quality_in_"+place+"-2014.csv",encoding = "unicode_escape")
    df["State"] = place
    print(place)
   
    df1 = df1.append(df, ignore_index=True)
    if df1.empty:
        df1 = df
        
df2['State'] = df1['State']
df = df1[df1.columns.difference(["STATION CODE","LOCATIONS","STATE"])];
df = df.drop(["State"],1)
# Out:
# andhra_pradesh
# assam
# bihar
# chattissgarh
# daman_diu_dadra_nagar_haveli
# goa
# himachal_pradesh
# kerala
# lakshadweep
# madhya_pradesh
# maharashtra
# odisha
# pondicherry
# punjab
# rajasthan
# tripura
# uttar_pradesh_uttarakhand
# west_bengal

# %%
df.isnull().sum().sum()
# Out:
# 1836

# %% [markdown]
# Now that all the datasets are combined into one, we can begin imputing. <br><br>
#
# ## Mean imputation
# First, a function is defined in order to impute a missing value with the mean of the feature.<br>
# We require this since there are several cases where more than one feature is missing per record.

# %%
def mean_imputation(df, feature):

    number_missing = df[feature].isnull().sum()
    observed_values = df.loc[df[feature].notnull(), feature]
    df.loc[df[feature].isnull(),feature + '_imp'] = np.mean(observed_values)
    
    return df

# %%
missing_columns = df.loc[:, df.isnull().any()].columns.values
print(missing_columns)
# Out:
# ['B.O.D. (mg/l) : Max : < 3 mg/l' 'B.O.D. (mg/l) : Mean : < 3 mg/l'
#  'B.O.D. (mg/l) : Min : < 3 mg/l' 'CONDUCTIVITY (µmhos/cm) : Max'
#  'CONDUCTIVITY (µmhos/cm) : Mean' 'CONDUCTIVITY (µmhos/cm) : Min'
#  'FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml'
#  'FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml'
#  'FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml'
#  'TEMPERATURE ºC : Max' 'TEMPERATURE ºC : Mean' 'TEMPERATURE ºC : Min'
#  'TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml'
#  'TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml'
#  'TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml']

# %% [markdown]
# We make a copy of the missing columns, to use it for the next step, regression imputation.

# %%
for feature in missing_columns:
    df[feature + '_imp'] = df[feature]
    df = mean_imputation(df, feature)

# %% [markdown]
# For each missing column, we use the mean imputed values as a part of the train set.
# The parameters are obtained and are used on the variable test, which contain the records<br>
# with the missing values. This is iterated through all the features.

# %% [markdown]
# ## Stochastic Regression Imputation
#
# Regression imputation leaves us with points that lie on the regression hyperplane.
# This isn't acceptable since it would overestimate the correlation between features.
# To overcome this, random values are generated with a normal distribution of the residual<br>
# variance of each feature.

# %%
for feature in missing_columns:
    remove = np.append(missing_columns,np.array(feature+"_imp"))
    x_train = df.loc[df[feature].notnull(),df.columns.difference(remove)]
    y_train = pd.DataFrame(df.loc[df[feature].notnull(),feature])
    std = np.var(y_train)
    
    test =  pd.DataFrame(df.loc[df[feature].isnull(),df.columns.difference(remove)])
    
    xt = x_train.values
    yt = y_train.values
    tt = test.values;
    preds = np.array(linReg(xt,yt,tt)) + np.random.normal(0,std,[test.shape[0],1])
    preds = np.reshape(preds,[preds.shape[0],])
    df.loc[df[feature].isnull(),feature] = preds 
    
            
df[df < 0] = 0

# %% [markdown]
# Since linear regression isn't a perfect fit, some of the data points go slightly below zero. <br>
# These data points are made zero, which is very common in the dataset.<br><br>
#
#
# The additional features designed are dropped, followed by addition of columns with strings in them.

# %%
for feature in missing_columns:
    df = df.drop([feature+"_imp"],1)

# %%
df["STATION CODE"]= df1["STATION CODE"]
df["LOCATIONS"] = df1["LOCATIONS"]
df["State"] = df2["State"]

# %%
df.columns
# Out:
# Index(['B.O.D. (mg/l) : Max : < 3 mg/l', 'B.O.D. (mg/l) : Mean : < 3 mg/l',
#        'B.O.D. (mg/l) : Min : < 3 mg/l', 'CONDUCTIVITY (µmhos/cm) : Max',
#        'CONDUCTIVITY (µmhos/cm) : Mean', 'CONDUCTIVITY (µmhos/cm) : Min',
#        'FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml',
#        'FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml',
#        'FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml',
#        'NITRATE- N+ NITRITE-N (mg/l) : Max',
#        'NITRATE- N+ NITRITE-N (mg/l) : Mean',
#        'NITRATE- N+ NITRITE-N (mg/l) : Min', 'TEMPERATURE ºC : Max',
#        'TEMPERATURE ºC : Mean', 'TEMPERATURE ºC : Min',
#        'TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml',
#        'TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml',
#        'TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml',
#        'pH : Max : 6.5-8.5', 'pH : Mean : 6.5-8.5', 'pH : Min : 6.5-8.5',
#        'STATION CODE', 'LOCATIONS', 'State'],
#       dtype='object')

# %% [markdown]
# Finally, the file is saved, ready to undergo PCA.

# %%
df.to_csv('../data_folder/filled_groundwater.csv')

# %%
df
# Out:
#      B.O.D. (mg/l) : Max : < 3 mg/l  B.O.D. (mg/l) : Mean : < 3 mg/l  \
# 0                        166.846451                         0.000000
# 1                        234.275167                        31.027603
# 2                          0.600000                         0.600000
# 3                          0.000000                        55.282050
# 4                          1.000000                         0.900000
# 5                          1.600000                         1.400000
# 6                          1.800000                         1.400000
# 7                          1.500000                         1.300000
# 8                          1.000000                         1.000000
# 9                          1.200000                         1.100000
# 10                         1.000000                         1.000000
# 11                         1.200000                         1.200000
# 12                         6.800000                         6.800000
# 13                         1.000000                         1.000000
# 14                         1.800000                         1.800000
# 15                       253.873528                        41.233049
# 16                       216.406781                        66.544459
# 17                         1.200000                         1.200000
# 18                         1.000000                         1.000000
# 19                         1.000000                         1.000000
# 20                         1.000000                         1.000000
# 21                         1.000000                         1.000000
# 22                        16.000000                        16.000000
# 23                        34.000000                        34.000000
# 24                        56.000000                        56.000000
# 25                        21.000000                        21.000000
# 26                        24.000000                        24.000000
# 27                        12.000000                        12.000000
# 28                       120.114726                       116.070118
# 29                         1.000000                         1.000000
# ..                              ...                              ...
# 441                        1.000000                         0.700000
# 442                        0.800000                         0.600000
# 443                        0.600000                         0.600000
# 444                        1.300000                         1.000000
# 445                        2.600000                         1.400000
# 446                        1.100000                         1.000000
# 447                        1.100000                         0.700000
# 448                        1.400000                         0.900000
# 449                        0.300000                         0.300000
# 450                        0.800000                         0.700000
# 451                        0.800000                         0.700000
# 452                        0.800000                         0.600000
# 453                        0.700000                         0.500000
# 454                        0.400000                         0.200000
# 455                        1.200000                         0.700000
# 456                        2.500000                         1.600000
# 457                        0.900000                         0.700000
# 458                        1.900000                         1.500000
# 459                        1.300000                         1.000000
# 460                        0.700000                         0.600000
# 461                        1.100000                         1.000000
# 462                        0.900000                         0.600000
# 463                        3.500000                         2.300000
# 464                        0.900000                         0.800000
# 465                        0.900000                         0.700000
# 466                        0.700000                         0.600000
# 467                        1.700000                         1.400000
# 468                        0.700000                         0.500000
# 469                        1.400000                         0.800000
# 470                        0.700000                         0.600000
#
#      B.O.D. (mg/l) : Min : < 3 mg/l  CONDUCTIVITY (µmhos/cm) : Max  \
# 0                          0.000000                         2050.0
# 1                         22.787722                         1639.0
# 2                          0.600000                         1569.0
# 3                          0.000000                         1119.0
# 4                          0.800000                         1950.0
# 5                          1.000000                         5000.0
# 6                          1.100000                         1510.0
# 7                          1.100000                         1100.0
# 8                          1.000000                         1790.0
# 9                          1.000000                         1343.0
# 10                         1.000000                          347.0
# 11                         1.200000                         1904.0
# 12                         6.800000                         3180.0
# 13                         1.000000                         1462.0
# 14                         1.800000                         4010.0
# 15                         0.000000                         1976.0
# 16                         0.000000                         1700.0
# 17                         1.200000                         2951.0
# 18                         1.000000                         2311.0
# 19                         1.000000                         2608.0
# 20                         1.000000                          911.0
# 21                         1.000000                         2096.0
# 22                        16.000000                          896.0
# 23                        34.000000                         1184.0
# 24                        56.000000                         1312.0
# 25                        21.000000                         1784.0
# 26                        24.000000                         1099.0
# 27                        12.000000                         1577.0
# 28                        38.654741                         1738.0
# 29                         1.000000                          497.0
# ..                              ...                            ...
# 441                        0.400000                         1472.0
# 442                        0.500000                          928.0
# 443                        0.600000                         1570.0
# 444                        0.700000                         2240.0
# 445                        0.100000                          384.0
# 446                        1.000000                          565.0
# 447                        0.300000                          410.0
# 448                        0.400000                         1441.0
# 449                        0.300000                          535.0
# 450                        0.600000                          116.0
# 451                        0.600000                          590.0
# 452                        0.400000                         1016.0
# 453                        0.200000                          500.0
# 454                        0.100000                          663.0
# 455                        0.200000                          101.0
# 456                        0.800000                          796.0
# 457                        0.400000                          714.0
# 458                        1.100000                          594.0
# 459                        0.700000                          929.0
# 460                        0.500000                          493.0
# 461                        0.900000                         1013.0
# 462                        0.300000                          801.0
# 463                        1.200000                          306.0
# 464                        0.800000                         1854.0
# 465                        0.400000                          814.0
# 466                        0.400000                          140.0
# 467                        1.100000                         1568.0
# 468                        0.300000                          987.0
# 469                        0.300000                         2140.0
# 470                        0.500000                         2040.0
#
#      CONDUCTIVITY (µmhos/cm) : Mean  CONDUCTIVITY (µmhos/cm) : Min  \
# 0                            2050.0                         2050.0
# 1                            1639.0                         1639.0
# 2                            1569.0                         1569.0
# 3                            1119.0                         1119.0
# 4                            1687.0                         1520.0
# 5                            3720.0                         2150.0
# 6                            1131.0                          730.0
# 7                             966.0                          723.0
# 8                            1790.0                         1790.0
# 9                             962.0                          771.0
# 10                            347.0                          347.0
# 11                           1904.0                         1904.0
# 12                           3180.0                         3180.0
# 13                           1462.0                         1462.0
# 14                           4010.0                         4010.0
# 15                           1976.0                         1976.0
# 16                           1700.0                         1700.0
# 17                           2951.0                         2951.0
# 18                           2311.0                         2311.0
# 19                           2608.0                         2608.0
# 20                            911.0                          911.0
# 21                           2096.0                         2096.0
# 22                            896.0                          896.0
# 23                           1184.0                         1184.0
# 24                           1312.0                         1312.0
# 25                           1784.0                         1784.0
# 26                           1099.0                         1099.0
# 27                           1577.0                         1577.0
# 28                           1738.0                         1738.0
# 29                            497.0                          497.0
# ..                              ...                            ...
# 441                          1461.0                         1450.0
# 442                           917.0                          905.0
# 443                          1520.0                         1470.0
# 444                          1979.0                         1717.0
# 445                           366.0                          348.0
# 446                           560.0                          554.0
# 447                           398.0                          385.0
# 448                          1345.0                         1248.0
# 449                           492.0                          448.0
# 450                           108.0                          100.0
# 451                           494.0                          398.0
# 452                          1012.0                         1008.0
# 453                           465.0                          429.0
# 454                           545.0                          426.0
# 455                            93.0                           85.0
# 456                           774.0                          752.0
# 457                           689.0                          663.0
# 458                           573.0                          552.0
# 459                           795.0                          660.0
# 460                           488.0                          482.0
# 461                           664.0                          314.0
# 462                           580.0                          358.0
# 463                           306.0                          306.0
# 464                          1791.0                         1727.0
# 465                           778.0                          742.0
# 466                           132.0                          123.0
# 467                          1027.0                          485.0
# 468                           978.0                          969.0
# 469                          1594.0                         1048.0
# 470                          1936.0                         1832.0
#
#      FECAL COLIFORM (MPN/100ml) : Max : < 2500 MPN/100ml  \
# 0                                         2.496179e+08
# 1                                         0.000000e+00
# 2                                         0.000000e+00
# 3                                         1.828890e+08
# 4                                         0.000000e+00
# 5                                         0.000000e+00
# 6                                         0.000000e+00
# 7                                         0.000000e+00
# 8                                         9.000000e+00
# 9                                         2.300000e+01
# 10                                        3.000000e+00
# 11                                        4.000000e+00
# 12                                        1.000000e+01
# 13                                        1.000000e+01
# 14                                        1.000000e+01
# 15                                        1.081300e+08
# 16                                        0.000000e+00
# 17                                        4.000000e+00
# 18                                        1.200000e+02
# 19                                        4.000000e+00
# 20                                        9.000000e+00
# 21                                        4.000000e+00
# 22                                        0.000000e+00
# 23                                        0.000000e+00
# 24                                        0.000000e+00
# 25                                        0.000000e+00
# 26                                        2.095568e+08
# 27                                        0.000000e+00
# 28                                        0.000000e+00
# 29                                        1.000000e+01
# ..                                                 ...
# 441                                       2.000000e+00
# 442                                       1.471413e+08
# 443                                       0.000000e+00
# 444                                       2.000000e+00
# 445                                       0.000000e+00
# 446                                       0.000000e+00
# 447                                       0.000000e+00
# 448                                       1.852526e+08
# 449                                       1.914677e+07
# 450                                       6.699184e+07
# 451                                       0.000000e+00
# 452                                       2.346788e+08
# 453                                       0.000000e+00
# 454                                       1.091900e+08
# 455                                       8.000000e+01
# 456                                       2.000000e+00
# 457                                       0.000000e+00
# 458                                       1.321265e+08
# 459                                       0.000000e+00
# 460                                       0.000000e+00
# 461                                       0.000000e+00
# 462                                       2.837120e+07
# 463                                       0.000000e+00
# 464                                       4.000000e+00
# 465                                       9.837499e+07
# 466                                       0.000000e+00
# 467                                       8.000000e+00
# 468                                       4.000000e+00
# 469                                       5.000000e+02
# 470                                       2.000000e+00
#
#      FECAL COLIFORM (MPN/100ml) : Mean : < 2500 MPN/100ml  \
# 0                                         1.251922e+08
# 1                                         1.925763e+07
# 2                                         1.784477e+08
# 3                                         5.651051e+07
# 4                                         0.000000e+00
# 5                                         0.000000e+00
# 6                                         0.000000e+00
# 7                                         0.000000e+00
# 8                                         9.000000e+00
# 9                                         1.600000e+01
# 10                                        3.000000e+00
# 11                                        4.000000e+00
# 12                                        1.000000e+01
# 13                                        1.000000e+01
# 14                                        1.000000e+01
# 15                                        2.480399e+07
# 16                                        0.000000e+00
# 17                                        4.000000e+00
# 18                                        1.200000e+02
# 19                                        4.000000e+00
# 20                                        9.000000e+00
# 21                                        4.000000e+00
# 22                                        7.595195e+07
# 23                                        5.030942e+07
# 24                                        7.744289e+07
# 25                                        5.151988e+07
# 26                                        0.000000e+00
# 27                                        0.000000e+00
# 28                                        0.000000e+00
# 29                                        1.000000e+01
# ..                                                 ...
# 441                                       2.000000e+00
# 442                                       1.071665e+08
# 443                                       2.997068e+07
# 444                                       2.000000e+00
# 445                                       0.000000e+00
# 446                                       0.000000e+00
# 447                                       0.000000e+00
# 448                                       9.375998e+07
# 449                                       1.054505e+07
# 450                                       1.750767e+08
# 451                                       7.740640e+06
# 452                                       0.000000e+00
# 453                                       1.172982e+08
# 454                                       0.000000e+00
# 455                                       7.500000e+01
# 456                                       2.000000e+00
# 457                                       0.000000e+00
# 458                                       0.000000e+00
# 459                                       2.661176e+07
# 460                                       0.000000e+00
# 461                                       9.288711e+07
# 462                                       0.000000e+00
# 463                                       5.708284e+07
# 464                                       4.000000e+00
# 465                                       0.000000e+00
# 466                                       0.000000e+00
# 467                                       8.000000e+00
# 468                                       4.000000e+00
# 469                                       5.000000e+02
# 470                                       2.000000e+00
#
#      FECAL COLIFORM (MPN/100ml) : Min : < 2500 MPN/100ml  \
# 0                                         7.711193e+07
# 1                                         0.000000e+00
# 2                                         1.204883e+07
# 3                                         2.591676e+07
# 4                                         0.000000e+00
# 5                                         0.000000e+00
# 6                                         0.000000e+00
# 7                                         0.000000e+00
# 8                                         9.000000e+00
# 9                                         4.000000e+00
# 10                                        3.000000e+00
# 11                                        4.000000e+00
# 12                                        1.000000e+01
# 13                                        1.000000e+01
# 14                                        1.000000e+01
# 15                                        0.000000e+00
# 16                                        7.816103e+07
# 17                                        4.000000e+00
# 18                                        1.200000e+02
# 19                                        4.000000e+00
# 20                                        9.000000e+00
# 21                                        4.000000e+00
# 22                                        0.000000e+00
# 23                                        3.085167e+07
# 24                                        0.000000e+00
# 25                                        3.476529e+07
# 26                                        0.000000e+00
# 27                                        0.000000e+00
# 28                                        1.330225e+07
# 29                                        1.000000e+01
# ..                                                 ...
# 441                                       2.000000e+00
# 442                                       8.813703e+06
# 443                                       0.000000e+00
# 444                                       2.000000e+00
# 445                                       0.000000e+00
# 446                                       0.000000e+00
# 447                                       0.000000e+00
# 448                                       5.398185e+07
# 449                                       7.581741e+06
# 450                                       2.234924e+07
# 451                                       3.770674e+07
# 452                                       3.471585e+07
# 453                                       0.000000e+00
# 454                                       2.616313e+07
# 455                                       7.000000e+01
# 456                                       2.000000e+00
# 457                                       0.000000e+00
# 458                                       3.861006e+07
# 459                                       4.083140e+07
# 460                                       2.150204e+07
# 461                                       0.000000e+00
# 462                                       0.000000e+00
# 463                                       2.052176e+07
# 464                                       4.000000e+00
# 465                                       0.000000e+00
# 466                                       7.421857e+07
# 467                                       8.000000e+00
# 468                                       4.000000e+00
# 469                                       5.000000e+02
# 470                                       2.000000e+00
#
#      NITRATE- N+ NITRITE-N (mg/l) : Max  ...  TEMPERATURE ºC : Min  \
# 0                                  2.50  ...                  23.0
# 1                                  1.20  ...                  23.0
# 2                                  2.80  ...                  19.0
# 3                                  0.50  ...                  29.0
# 4                                  8.00  ...                  27.0
# 5                                 14.00  ...                  27.0
# 6                                  3.10  ...                  27.0
# 7                                 11.50  ...                  27.0
# 8                                  5.40  ...                  25.0
# 9                                  1.80  ...                  25.0
# 10                                 0.20  ...                  27.0
# 11                                 1.50  ...                  26.0
# 12                                 8.00  ...                  32.0
# 13                                 5.00  ...                  28.0
# 14                                 2.00  ...                  29.0
# 15                                 5.20  ...                  23.0
# 16                                 0.70  ...                  20.0
# 17                                 4.70  ...                  25.0
# 18                                 8.60  ...                  26.0
# 19                                 8.80  ...                  25.0
# 20                                 3.50  ...                  25.0
# 21                                 6.30  ...                  25.0
# 22                                 0.00  ...                   0.0
# 23                                 0.00  ...                   0.0
# 24                                 0.00  ...                   0.0
# 25                                 0.00  ...                   0.0
# 26                                 0.00  ...                   0.0
# 27                                 0.00  ...                   0.0
# 28                                 0.95  ...                  22.0
# 29                                 3.00  ...                  30.0
# ..                                  ...  ...                   ...
# 441                                0.20  ...                  28.5
# 442                                0.10  ...                  27.0
# 443                                0.30  ...                  27.0
# 444                                1.10  ...                  31.0
# 445                                0.40  ...                  25.0
# 446                                1.00  ...                  27.5
# 447                                0.40  ...                  28.0
# 448                                0.40  ...                  33.0
# 449                                0.00  ...                  31.0
# 450                                1.50  ...                  30.0
# 451                                1.10  ...                  24.0
# 452                                0.00  ...                  27.0
# 453                                0.70  ...                  26.0
# 454                                0.30  ...                  27.0
# 455                                0.30  ...                  26.0
# 456                                0.50  ...                  29.0
# 457                                0.70  ...                  28.0
# 458                                0.40  ...                  66.0
# 459                                0.80  ...                  29.0
# 460                                0.20  ...                  30.0
# 461                                6.60  ...                  29.0
# 462                                2.60  ...                  28.0
# 463                                0.70  ...                  29.0
# 464                                0.20  ...                  28.0
# 465                                0.10  ...                  26.0
# 466                                3.40  ...                  26.0
# 467                                4.10  ...                  27.0
# 468                                0.80  ...                  26.0
# 469                                0.60  ...                  26.0
# 470                                0.20  ...                  27.0
#
#      TOTAL COLIFORM (MPN/100ml) : Max : < 5000 MPN/100ml  \
# 0                                         4.000000e+02
# 1                                         4.000000e+02
# 2                                         4.000000e+02
# 3                                         4.000000e+02
# 4                                         4.000000e+01
# 5                                         5.000000e+01
# 6                                         3.000000e+01
# 7                                         4.000000e+01
# 8                                         1.200000e+02
# 9                                         1.500000e+02
# 10                                        1.400000e+01
# 11                                        4.000000e+00
# 12                                        8.600000e+01
# 13                                        6.400000e+01
# 14                                        3.200000e+01
# 15                                        4.000000e+02
# 16                                        4.000000e+02
# 17                                        9.000000e+00
# 18                                        2.400000e+03
# 19                                        2.800000e+01
# 20                                        1.200000e+02
# 21                                        1.100000e+01
# 22                                        3.289486e+09
# 23                                        0.000000e+00
# 24                                        9.338586e+09
# 25                                        0.000000e+00
# 26                                        0.000000e+00
# 27                                        0.000000e+00
# 28                                        4.000000e+02
# 29                                        2.400000e+01
# ..                                                 ...
# 441                                       8.000000e+00
# 442                                       0.000000e+00
# 443                                       1.349816e+10
# 444                                       3.000000e+00
# 445                                       0.000000e+00
# 446                                       0.000000e+00
# 447                                       0.000000e+00
# 448                                       0.000000e+00
# 449                                       1.140116e+10
# 450                                       3.578739e+09
# 451                                       3.238076e+07
# 452                                       0.000000e+00
# 453                                       0.000000e+00
# 454                                       1.286517e+10
# 455                                       1.400000e+02
# 456                                       4.000000e+00
# 457                                       5.552508e+09
# 458                                       7.746483e+09
# 459                                       0.000000e+00
# 460                                       5.568993e+08
# 461                                       1.019483e+10
# 462                                       4.844633e+09
# 463                                       5.576132e+09
# 464                                       1.300000e+01
# 465                                       1.137674e+10
# 466                                       0.000000e+00
# 467                                       1.300000e+01
# 468                                       1.300000e+01
# 469                                       9.000000e+02
# 470                                       1.100000e+01
#
#      TOTAL COLIFORM (MPN/100ml) : Mean : < 5000 MPN/100ml  \
# 0                                         4.000000e+02
# 1                                         4.000000e+02
# 2                                         4.000000e+02
# 3                                         4.000000e+02
# 4                                         3.200000e+01
# 5                                         3.600000e+01
# 6                                         3.000000e+01
# 7                                         3.400000e+01
# 8                                         1.200000e+02
# 9                                         8.400000e+01
# 10                                        1.400000e+01
# 11                                        4.000000e+00
# 12                                        8.600000e+01
# 13                                        6.400000e+01
# 14                                        3.200000e+01
# 15                                        4.000000e+02
# 16                                        4.000000e+02
# 17                                        9.000000e+00
# 18                                        2.400000e+03
# 19                                        2.800000e+01
# 20                                        1.200000e+02
# 21                                        1.100000e+01
# 22                                        1.930580e+08
# 23                                        9.520457e+08
# 24                                        0.000000e+00
# 25                                        0.000000e+00
# 26                                        8.446226e+08
# 27                                        7.900094e+08
# 28                                        4.000000e+02
# 29                                        2.400000e+01
# ..                                                 ...
# 441                                       8.000000e+00
# 442                                       4.143442e+08
# 443                                       0.000000e+00
# 444                                       3.000000e+00
# 445                                       0.000000e+00
# 446                                       0.000000e+00
# 447                                       0.000000e+00
# 448                                       8.720830e+08
# 449                                       1.816393e+08
# 450                                       0.000000e+00
# 451                                       0.000000e+00
# 452                                       3.302520e+08
# 453                                       0.000000e+00
# 454                                       0.000000e+00
# 455                                       1.300000e+02
# 456                                       4.000000e+00
# 457                                       1.048582e+09
# 458                                       0.000000e+00
# 459                                       9.610153e+08
# 460                                       1.091049e+09
# 461                                       4.146092e+08
# 462                                       1.599802e+08
# 463                                       0.000000e+00
# 464                                       1.300000e+01
# 465                                       0.000000e+00
# 466                                       1.082804e+06
# 467                                       1.300000e+01
# 468                                       1.300000e+01
# 469                                       9.000000e+02
# 470                                       1.100000e+01
#
#      TOTAL COLIFORM (MPN/100ml) : Min : < 5000 MPN/100ml  pH : Max : 6.5-8.5  \
# 0                                         4.000000e+02                   7.0
# 1                                         4.000000e+02                   7.3
# 2                                         4.000000e+02                   7.4
# 3                                         4.000000e+02                   7.4
# 4                                         2.000000e+01                   8.1
# 5                                         2.000000e+01                   8.2
# 6                                         3.000000e+01                   8.1
# 7                                         2.000000e+01                   8.3
# 8                                         1.200000e+02                   7.7
# 9                                         4.000000e+00                   7.7
# 10                                        1.400000e+01                   7.9
# 11                                        4.000000e+00                   7.4
# 12                                        8.600000e+01                   7.7
# 13                                        6.400000e+01                   7.5
# 14                                        3.200000e+01                   6.9
# 15                                        4.000000e+02                   7.1
# 16                                        4.000000e+02                   7.2
# 17                                        9.000000e+00                   7.7
# 18                                        2.400000e+03                   7.2
# 19                                        2.800000e+01                   7.8
# 20                                        1.200000e+02                   7.6
# 21                                        1.100000e+01                   7.9
# 22                                        5.742119e+07                   7.6
# 23                                        0.000000e+00                   7.9
# 24                                        0.000000e+00                   8.1
# 25                                        3.558784e+06                   8.1
# 26                                        9.076952e+07                   8.0
# 27                                        0.000000e+00                   7.6
# 28                                        4.000000e+02                   7.3
# 29                                        2.400000e+01                   7.9
# ..                                                 ...                   ...
# 441                                       8.000000e+00                   7.4
# 442                                       4.137825e+07                   7.6
# 443                                       0.000000e+00                   8.0
# 444                                       3.000000e+00                   8.5
# 445                                       0.000000e+00                   8.4
# 446                                       0.000000e+00                   7.8
# 447                                       0.000000e+00                   7.8
# 448                                       0.000000e+00                   7.5
# 449                                       0.000000e+00                   7.5
# 450                                       4.774450e+07                   7.4
# 451                                       0.000000e+00                   7.6
# 452                                       0.000000e+00                   7.5
# 453                                       6.225750e+07                   7.9
# 454                                       0.000000e+00                   8.0
# 455                                       1.200000e+02                   7.4
# 456                                       4.000000e+00                   7.5
# 457                                       0.000000e+00                   7.5
# 458                                       0.000000e+00                   9.3
# 459                                       0.000000e+00                   7.4
# 460                                       0.000000e+00                   7.3
# 461                                       0.000000e+00                   7.1
# 462                                       8.203306e+07                   8.0
# 463                                       3.477704e+07                   7.0
# 464                                       1.300000e+01                   7.5
# 465                                       0.000000e+00                   6.7
# 466                                       3.567339e+07                   8.0
# 467                                       1.300000e+01                   7.5
# 468                                       1.300000e+01                   8.0
# 469                                       9.000000e+02                   8.0
# 470                                       1.100000e+01                   7.5
#
#      pH : Mean : 6.5-8.5  pH : Min : 6.5-8.5  STATION CODE  \
# 0                    7.0                 7.0        1513.0
# 1                    7.3                 7.3        1514.0
# 2                    7.4                 7.4        1515.0
# 3                    7.4                 7.4        1516.0
# 4                    7.9                 7.2        1517.0
# 5                    7.9                 7.8        1518.0
# 6                    7.9                 7.8        1519.0
# 7                    7.9                 7.6        1520.0
# 8                    7.7                 7.7        1521.0
# 9                    7.4                 7.2        1522.0
# 10                   7.9                 7.9        1523.0
# 11                   7.4                 7.4        1524.0
# 12                   7.7                 7.7        1795.0
# 13                   7.5                 7.5        1810.0
# 14                   6.9                 6.9        1811.0
# 15                   7.1                 7.1        3087.0
# 16                   7.2                 7.2        3088.0
# 17                   7.7                 7.7        3089.0
# 18                   7.2                 7.2        3090.0
# 19                   7.8                 7.8        3091.0
# 20                   7.6                 7.6        3092.0
# 21                   7.9                 7.9        3093.0
# 22                   7.6                 7.6        3094.0
# 23                   7.9                 7.9        1791.0
# 24                   8.1                 8.1        1792.0
# 25                   8.1                 8.1        1793.0
# 26                   8.0                 8.0        1794.0
# 27                   7.6                 7.6          16.0
# 28                   7.3                 7.3          26.0
# 29                   7.9                 7.9          27.0
# ..                   ...                 ...           ...
# 441                  7.2                 7.1        1935.0
# 442                  7.6                 7.5        1936.0
# 443                  7.7                 7.5        1937.0
# 444                  8.3                 8.2        1938.0
# 445                  7.9                 7.3        1939.0
# 446                  7.6                 7.4        1940.0
# 447                  7.6                 7.5        1941.0
# 448                  7.4                 7.3        1942.0
# 449                  7.3                 7.1        1943.0
# 450                  7.3                 7.2        1944.0
# 451                  7.3                 7.0        1945.0
# 452                  7.3                 7.2        2510.0
# 453                  7.5                 7.2        2515.0
# 454                  7.6                 7.1        2516.0
# 455                  7.2                 7.0        2526.0
# 456                  7.3                 7.1        2528.0
# 457                  7.1                 6.8        2529.0
# 458                  9.3                 9.3        2530.0
# 459                  6.7                 6.1        2533.0
# 460                  7.1                 6.9        2535.0
# 461                  7.1                 7.1        2536.0
# 462                  7.5                 7.0        2537.0
# 463                  7.0                 7.0        2538.0
# 464                  7.5                 7.5        2540.0
# 465                  6.7                 6.6        2542.0
# 466                  6.9                 5.7        2543.0
# 467                  7.1                 6.8        2545.0
# 468                  7.9                 7.9        2546.0
# 469                  7.5                 7.1        2547.0
# 470                  7.4                 7.2        2548.0
#
#                                              LOCATIONS           State
# 0    B W. - KRISHNA MURTHY, D.NO. 48-16-43 AUTONAGA...  andhra_pradesh
# 1    B/W. - VIJAY KUMAR AUTONAGAR VIJAYAWADA, KRISH...  andhra_pradesh
# 2    B/W. - NAGARAM(V), PALVONCHA, KHAMMAM DIST., A.P.  andhra_pradesh
# 3                     B W OF NAVLOK GARDENS NELLORE AP  andhra_pradesh
# 4           B/W. - TUNGBHADRA RIVER NEAR KURNOOL, A.P.  andhra_pradesh
# 5                  B/W. - NANDYAL, KURNOOL DIST., A.P.  andhra_pradesh
# 6                   B/W. - NAGIRI, CHITTOOR DIST., A.P  andhra_pradesh
# 7    B/W. - SWARNAMUKHI RIVER, SRIKALAHASTI, CHITTO...  andhra_pradesh
# 8    O/W. - NEAR RAMA TEMPLE , WARD NO.2 , MINDI , ...  andhra_pradesh
# 9                  O/W. PEDDANUYYI - VIZIANAGARAM, A.P  andhra_pradesh
# 10   B/W. - NEAR M/S ANDHRA SUGARS LTD. , KOVVUR , ...  andhra_pradesh
# 11   O/W. -NEAR PARTAP NAGAR BRIIDGE -KAKINADA , E....  andhra_pradesh
# 12   B/W. - PANCHAYAT OFFICE , , BOLLARAM (V) MEDAK...  andhra_pradesh
# 13   B/W - SRI RAMNAGAR COLONY, SAKKAR NAGAR, BODHA...  andhra_pradesh
# 14   B/W. - PRIMARY SCHOOL - RUDRAVELLI (V) , BIBIN...  andhra_pradesh
# 15   BORE WELL NEAR VILLAGE SECRETARIAT, PATHAPADU ...  andhra_pradesh
# 16   B/W AT J.NARASIMHA RAOS HOUSE, 14NOS. AREA, R...  andhra_pradesh
# 17      HAND PUMP AT TANAM VILL., VISHAKHAPATNAM, A.P.  andhra_pradesh
# 18   HAND PUMP AT PITTAVANIPALEM, VISHAKHAPATNAM , ...  andhra_pradesh
# 19   BORE WELL AT KAPULUPPADA DUMPSITE, VISHAKHAPAT...  andhra_pradesh
# 20   BORE WELL AT ARINAMA AKKIVALASA, SRIKAKULAM, A.P.  andhra_pradesh
# 21   B/W AT ALLADAPALEM VILLAGE, PYDIBHIMAVARAM, DI...  andhra_pradesh
# 22                Bore well at Akbarnagar, Ramagundam   andhra_pradesh
# 23   Borewell at Pydipally near East side of Sai ch...  andhra_pradesh
# 24                 Borewell at CKM College, Enamamula   andhra_pradesh
# 25    Open well at Kundanpally near ash ponds of NTPC   andhra_pradesh
# 26                             Borewell at Manakondur   andhra_pradesh
# 27                               Open well at Tadavai   andhra_pradesh
# 28                              Borewell at Vijayawada  andhra_pradesh
# 29                                  B/w at Peddavoora   andhra_pradesh
# ..                                                 ...             ...
# 441                     INSIDE KOLKATA LEATHER COMPLEX     west_bengal
# 442                       RESIDENTIAL AREA AT SONARPUR     west_bengal
# 443                            RAJARHAT - NEW TOWNSHIP     west_bengal
# 444                              BASIRHAT MUNICIPALITY     west_bengal
# 445                            BARRAKPORE MUNICIPALITY     west_bengal
# 446                  NEAR THE PHOSPHATE COMPANY-RISHRA     west_bengal
# 447        NEAR FLY ASH DUMPING SITE-KUNTIGHAT, BANDEL     west_bengal
# 448                       NEAR EXIDE INDUSTRIES-HALDIA     west_bengal
# 449                    INSIDE TATA METALIKS, KHARAGPUR     west_bengal
# 450                          KHARAGPUR INDUSTRIAL AREA     west_bengal
# 451                              ENGLISH BAZAR- MALDAH     west_bengal
# 452                     GEOKHALI BUNGLOW MIDNAPUR-EAST     west_bengal
# 453                               SDO OFFICE, RANAGHAT     west_bengal
# 454                           SDO OFFICE, KRISHNANAGAR     west_bengal
# 455                                    FULBARI BARRAGE     west_bengal
# 456       GROUND WATER POINT INSIDE BURDWAN UNIVERSITY     west_bengal
# 457            GROUND WATER POINT NEAR BURDWAN STATION     west_bengal
# 458                           HOT SPRING AT BAKRESHWAR     west_bengal
# 459                           SURI TOWN NEAR BUS STAND     west_bengal
# 460                                      VISVA BHARATI     west_bengal
# 461                 NALHATI RAILWAY STATION OF BIRBHUM     west_bengal
# 462                        BOLPUR NEAR RAILWAY STATION     west_bengal
# 463                                  MOREGRAM CROSSING     west_bengal
# 464                          SATI GHAT AT BANKURA TOWN     west_bengal
# 465                          DWARIKA AT BISHNUPUR TOWN     west_bengal
# 466                       SDO OFFICE AT BISHNUPUR TOWN     west_bengal
# 467           GROUND WATER POINT AT PURULIA RK MISSION     west_bengal
# 468                         ULUBERIA COLLEGE AT HOWRAH     west_bengal
# 469    AMTOLA ON DIAMOND HARBOUR ROAD, 24 PARGANAS (S)     west_bengal
# 470                             HIDCO OFFICE, RAJARHAT     west_bengal
#
# [471 rows x 24 columns]
